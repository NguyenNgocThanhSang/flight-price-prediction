# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
# Nhập các thư viện cần thiết
import matplotlib.pyplot as plt  # Matplotlib để vẽ đồ thị cơ bản
import seaborn as sns  # Seaborn để trực quan hóa dữ liệu thống kê
import pandas as pd  # Pandas để thực hiện các thao tác xử lý và phân tích dữ liệu
import plotly.express as px  # Plotly Express để tạo đồ thị tương tác
from bokeh.plotting import figure, show  # Bokeh để vẽ đồ thị tương tác
import altair as alt  # Altair để trực quan hóa thống kê theo cách khai báo
import numpy as np
import plotly.express as px
import plotly.graph_objs as go
import matplotlib.pyplot as plt
sns.set_style('ticks')
sns.set_palette("viridis")
from sklearn.preprocessing import MinMaxScaler, StandardScaler  # MinMaxScaler để chuẩn hóa dữ liệu về khoảng [0, 1]
from sklearn.preprocessing import LabelEncoder, OneHotEncoder  # LabelEncoder để mã hóa biến đối số
from sklearn.model_selection import train_test_split  # train_test_split để chia dữ liệu thành tập huấn luyện và tập kiểm thử

# Nhập các mô hình học máy
from sklearn.linear_model import LinearRegression, Lasso  # Mô hình hồi quy tuyến tính
from sklearn.tree import DecisionTreeRegressor  # Mô hình hồi quy cây quyết định
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor  # Mô hình hồi quy RandomForest và Bagging
from sklearn import metrics  # Thư viện đánh giá hiệu suất mô hình

# Tắt cả các cảnh báo để giữ mã nguồn sạch sẽ và tránh hiển thị cảnh báo không cần thiết
import warnings
warnings.filterwarnings('ignore')

# %%
flights = pd.read_csv('/content/gdrive/MyDrive/Clean_Dataset.csv')

# %%
flights = flights.drop(columns='Unnamed: 0', axis=1)

# %%
flights.head(10)
# Out:
#     airline   flight source_city departure_time stops   arrival_time  \
# 0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4   Vistara   UK-963       Delhi        Morning  zero        Morning
# 5   Vistara   UK-945       Delhi        Morning  zero      Afternoon
# 6   Vistara   UK-927       Delhi        Morning  zero        Morning
# 7   Vistara   UK-951       Delhi      Afternoon  zero        Evening
# 8  GO_FIRST   G8-334       Delhi  Early_Morning  zero        Morning
# 9  GO_FIRST   G8-336       Delhi      Afternoon  zero        Evening
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# 1           Mumbai  Economy      2.33          1   5953
# 2           Mumbai  Economy      2.17          1   5956
# 3           Mumbai  Economy      2.25          1   5955
# 4           Mumbai  Economy      2.33          1   5955
# 5           Mumbai  Economy      2.33          1   5955
# 6           Mumbai  Economy      2.08          1   6060
# 7           Mumbai  Economy      2.17          1   6060
# 8           Mumbai  Economy      2.17          1   5954
# 9           Mumbai  Economy      2.25          1   5954

# %% [markdown]
# ## Tiền xử lý data

# %%
fl = flights.copy()

# %%
fl
# Out:
#          airline   flight source_city departure_time stops   arrival_time  \
# 0       SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1       SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2        AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3        Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4        Vistara   UK-963       Delhi        Morning  zero        Morning
# ...          ...      ...         ...            ...   ...            ...
# 300148   Vistara   UK-822     Chennai        Morning   one        Evening
# 300149   Vistara   UK-826     Chennai      Afternoon   one          Night
# 300150   Vistara   UK-832     Chennai  Early_Morning   one          Night
# 300151   Vistara   UK-828     Chennai  Early_Morning   one        Evening
# 300152   Vistara   UK-822     Chennai        Morning   one        Evening
#
#        destination_city     class  duration  days_left  price
# 0                Mumbai   Economy      2.17          1   5953
# 1                Mumbai   Economy      2.33          1   5953
# 2                Mumbai   Economy      2.17          1   5956
# 3                Mumbai   Economy      2.25          1   5955
# 4                Mumbai   Economy      2.33          1   5955
# ...                 ...       ...       ...        ...    ...
# 300148        Hyderabad  Business     10.08         49  69265
# 300149        Hyderabad  Business     10.42         49  77105
# 300150        Hyderabad  Business     13.83         49  79099
# 300151        Hyderabad  Business     10.00         49  81585
# 300152        Hyderabad  Business     10.08         49  81585
#
# [300153 rows x 11 columns]

# %% [markdown]
# - mã hóa dữ liệu

# %%
# Coverting the labels into a numeric form using Label Encoder
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for col in flights.columns:
    if fl[col].dtype=='object':
        fl[col]=le.fit_transform(fl[col])

# %% [markdown]
# - chuẩn hóa dữ liệu

# %%
fl.describe()
# Out:
#              airline         flight    source_city  departure_time  \
# count  300153.000000  300153.000000  300153.000000   300153.000000
# mean        3.104873    1088.336618       2.577592        2.417337
# std         1.833265     426.694820       1.751762        1.754276
# min         0.000000       0.000000       0.000000        0.000000
# 25%         1.000000     783.000000       1.000000        1.000000
# 50%         3.000000    1142.000000       2.000000        2.000000
# 75%         5.000000    1486.000000       4.000000        4.000000
# max         5.000000    1560.000000       5.000000        5.000000
#
#                stops   arrival_time  destination_city          class  \
# count  300153.000000  300153.000000     300153.000000  300153.000000
# mean        0.284168       3.074086          2.588303       0.688536
# std         0.665825       1.741666          1.744543       0.463093
# min         0.000000       0.000000          0.000000       0.000000
# 25%         0.000000       2.000000          1.000000       0.000000
# 50%         0.000000       4.000000          3.000000       1.000000
# 75%         0.000000       5.000000          4.000000       1.000000
# max         2.000000       5.000000          5.000000       1.000000
#
#             duration      days_left          price
# count  300153.000000  300153.000000  300153.000000
# mean       12.221021      26.004751   20889.660523
# std         7.191997      13.561004   22697.767366
# min         0.830000       1.000000    1105.000000
# 25%         6.830000      15.000000    4783.000000
# 50%        11.250000      26.000000    7425.000000
# 75%        16.170000      38.000000   42521.000000
# max        49.830000      49.000000  123071.000000

# %% [markdown]
# - chia dữ liệu

# %%
# storing the Dependent Variables in X and Independent Variable in Y
x=fl.drop(['price'],axis=1)
y=fl['price']

# %%
scaler=StandardScaler()
x = scaler.fit_transform(x)

# %%
# Splitting the Data into Training set and Testing Set
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x, y, test_size=0.30, random_state=42)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((210107, 10), (90046, 10), (210107,), (90046,))

# %%
# x_train=scaler.fit_transform(x_train)
# x_test=scaler.transform(x_test)
# x_train=pd.DataFrame(x_train)
# x_test=pd.DataFrame(x_test)

# %% [markdown]
# ### Build Model

# %%
a={'Model Name':[], 'Mean_Absolute_Error_MAE':[] ,'Adj_R_Square':[] ,'Root_Mean_Squared_Error_RMSE':[] ,'Mean_Absolute_Percentage_Error_MAPE':[] ,'Mean_Squared_Error_MSE':[] ,'Root_Mean_Squared_Log_Error_RMSLE':[] ,'R2_score':[]}
Results=pd.DataFrame(a)
Results.head()
# Out:
# Empty DataFrame
# Columns: [Model Name, Mean_Absolute_Error_MAE, Adj_R_Square, Root_Mean_Squared_Error_RMSE, Mean_Absolute_Percentage_Error_MAPE, Mean_Squared_Error_MSE, Root_Mean_Squared_Log_Error_RMSLE, R2_score]
# Index: []

# %%
# Create objects of Regression / Regressor models with default hyper-parameters

modelmlg = LinearRegression()
modeldcr = DecisionTreeRegressor()
modelrfr = RandomForestRegressor()
modelETR = ExtraTreesRegressor()
modelLO = Lasso(alpha=0.1)


# Evalution matrix for all the algorithms

MM = [modelmlg, modeldcr, modelrfr,modelETR,modelLO]
# MM = [modelLO]

for models in MM:

    # Fit the model with train data

    models.fit(x_train, y_train)

    # Predict the model with test data

    y_pred = models.predict(x_test)

    # Print the model name

    print('Model Name: ', models)

    # Evaluation metrics for Regression analysis

    from sklearn import metrics

    print('Mean Absolute Error (MAE):', round(metrics.mean_absolute_error(y_test, y_pred),3))
    print('Mean Squared Error (MSE):', round(metrics.mean_squared_error(y_test, y_pred),3))
    print('Root Mean Squared Error (RMSE):', round(np.sqrt(metrics.mean_squared_error(y_test, y_pred)),3))
    print('R2_score:', round(metrics.r2_score(y_test, y_pred),6))
    print('Root Mean Squared Log Error (RMSLE):', round(np.log(np.sqrt(metrics.mean_squared_error(y_test, y_pred))),3))

    # Define the function to calculate the MAPE - Mean Absolute Percentage Error

    def MAPE (y_test, y_pred):
        y_test, y_pred = np.array(y_test), np.array(y_pred)
        return np.mean(np.abs((y_test - y_pred) / y_test)) * 100

    # Evaluation of MAPE

    result = MAPE(y_test, y_pred)
    print('Mean Absolute Percentage Error (MAPE):', round(result, 2), '%')

    # Calculate Adjusted R squared values

    r_squared = round(metrics.r2_score(y_test, y_pred),6)
    adjusted_r_squared = round(1 - (1-r_squared)*(len(y)-1)/(len(y)-x.shape[1]-1),6)
    print('Adj R Square: ', adjusted_r_squared)
    print('------------------------------------------------------------------------------------------------------------')
    #-------------------------------------------------------------------------------------------
    new_row = {'Model Name' : models,
               'Mean_Absolute_Error_MAE' : metrics.mean_absolute_error(y_test, y_pred),
               'Adj_R_Square' : adjusted_r_squared,
               'Root_Mean_Squared_Error_RMSE' : np.sqrt(metrics.mean_squared_error(y_test, y_pred)),
               'Mean_Absolute_Percentage_Error_MAPE' : result,
               'Mean_Squared_Error_MSE' : metrics.mean_squared_error(y_test, y_pred),
               'Root_Mean_Squared_Log_Error_RMSLE': np.log(np.sqrt(metrics.mean_squared_error(y_test, y_pred))),
               'R2_score' : metrics.r2_score(y_test, y_pred)}
    Results = Results.append(new_row, ignore_index=True)
    #------------------------------------------------------------
# Out:
# Model Name:  LinearRegression()
# Mean Absolute Error (MAE): 4623.409
# Mean Squared Error (MSE): 49062056.15
# Root Mean Squared Error (RMSE): 7004.431
# R2_score: 0.904672
# Root Mean Squared Log Error (RMSLE): 8.854
# Mean Absolute Percentage Error (MAPE): 43.66 %
# Adj R Square:  0.904669
# ------------------------------------------------------------------------------------------------------------
# Model Name:  DecisionTreeRegressor()
# Mean Absolute Error (MAE): 917.537
# Mean Squared Error (MSE): 8943170.183
# Root Mean Squared Error (RMSE): 2990.513
# R2_score: 0.982623
# Root Mean Squared Log Error (RMSLE): 8.003
# Mean Absolute Percentage Error (MAPE): 6.3 %
# Adj R Square:  0.982622
# ------------------------------------------------------------------------------------------------------------
# Model Name:  RandomForestRegressor()
# Mean Absolute Error (MAE): 898.873
# Mean Squared Error (MSE): 5706249.275
# Root Mean Squared Error (RMSE): 2388.776
# R2_score: 0.988913
# Root Mean Squared Log Error (RMSLE): 7.779
# Mean Absolute Percentage Error (MAPE): 6.05 %
# Adj R Square:  0.988913
# ------------------------------------------------------------------------------------------------------------
# Model Name:  ExtraTreesRegressor()
# Mean Absolute Error (MAE): 942.852
# Mean Squared Error (MSE): 6509400.658
# Root Mean Squared Error (RMSE): 2551.353
# R2_score: 0.987352
# Root Mean Squared Log Error (RMSLE): 7.844
# Mean Absolute Percentage Error (MAPE): 6.41 %
# Adj R Square:  0.987352
# ------------------------------------------------------------------------------------------------------------
# Model Name:  Lasso(alpha=0.1)
# Mean Absolute Error (MAE): 4623.372
# Mean Squared Error (MSE): 49062032.473
# Root Mean Squared Error (RMSE): 7004.429
# R2_score: 0.904672
# Root Mean Squared Log Error (RMSLE): 8.854
# Mean Absolute Percentage Error (MAPE): 43.66 %
# Adj R Square:  0.904669
# ------------------------------------------------------------------------------------------------------------

# %%
models=['LinearRegression','DecisionTreeRegressor','RandomForestRegressor','ExtraTreesRegressor','Lasso Regression']
result=pd.DataFrame({'Model_Name':models})
result['Adj_R_Square']=Results['Adj_R_Square']
result['Mean_Absolute_Error_MAE']=Results['Mean_Absolute_Error_MAE']
result['Root_Mean_Squared_Error_RMSE']=Results['Root_Mean_Squared_Error_RMSE']
result['Mean_Absolute_Percentage_Error_MAPE']=Results['Mean_Absolute_Percentage_Error_MAPE']
result['Mean_Squared_Error_MSE']=Results['Mean_Squared_Error_MSE']
result['Root_Mean_Squared_Log_Error_RMSLE']=Results['Root_Mean_Squared_Log_Error_RMSLE']
result['R2_score']=Results['R2_score']
result=result.sort_values(by='Adj_R_Square',ascending=False).reset_index(drop=True)
result
# Out:
#               Model_Name  Adj_R_Square  Mean_Absolute_Error_MAE  \
# 0  RandomForestRegressor      0.988913               898.873394
# 1    ExtraTreesRegressor      0.987352               942.851828
# 2  DecisionTreeRegressor      0.982622               917.536557
# 3       LinearRegression      0.904669              4623.408800
# 4       Lasso Regression      0.904669              4623.371724
#
#    Root_Mean_Squared_Error_RMSE  Mean_Absolute_Percentage_Error_MAPE  \
# 0                   2388.775685                             6.051336
# 1                   2551.352711                             6.406528
# 2                   2990.513365                             6.297622
# 3                   7004.431180                            43.663631
# 4                   7004.429489                            43.662549
#
#    Mean_Squared_Error_MSE  Root_Mean_Squared_Log_Error_RMSLE  R2_score
# 0            5.706249e+06                           7.778536  0.988913
# 1            6.509401e+06                           7.844379  0.987352
# 2            8.943170e+06                           8.003200  0.982623
# 3            4.906206e+07                           8.854298  0.904672
# 4            4.906203e+07                           8.854298  0.904672

# %%
#Trainig the model with
modelrfr.fit(x_train, y_train)

# Predict the model with test data

y_pred = modelrfr.predict(x_test)

# %%
out=pd.DataFrame({'Price_actual':y_test, 'Price_pred':y_pred})
result=flights.merge(out,left_index=True,right_index=True)

# %%
result.sample(100)
# Out:
#           airline   flight source_city departure_time stops arrival_time  \
# 291541    Vistara   UK-838     Chennai          Night   one      Evening
# 11363     Vistara   UK-995       Delhi        Morning   one      Evening
# 189930  Air_India   AI-539     Chennai        Evening   one    Afternoon
# 83616     Vistara   UK-928      Mumbai  Early_Morning   one        Night
# 204174     Indigo  6E-7261     Chennai      Afternoon   one      Evening
# ...           ...      ...         ...            ...   ...          ...
# 46592     Vistara   UK-821      Mumbai  Early_Morning   one      Evening
# 189825     Indigo  6E-6111     Chennai        Morning  zero      Morning
# 125996     Indigo  6E-6917     Kolkata      Afternoon   one        Night
# 232799  Air_India   AI-607      Mumbai        Evening  zero      Evening
# 136148  Air_India   AI-424     Kolkata      Afternoon   one        Night
#
#        destination_city     class  duration  days_left  price  Price_actual  \
# 291541           Mumbai  Business     22.00         20  86480         86480
# 11363         Bangalore   Economy      8.92          9  10680         10680
# 189930           Mumbai   Economy     20.42         20   7427          7427
# 83616           Chennai   Economy     16.25         46   4249          4249
# 204174        Hyderabad   Economy      5.00         19   6885          6885
# ...                 ...       ...       ...        ...    ...           ...
# 46592             Delhi   Economy     13.17         20   5445          5445
# 189825           Mumbai   Economy      1.92         20   3000          3000
# 125996            Delhi   Economy      5.42         41   2994          2994
# 232799        Bangalore  Business      1.75         34  20684         20684
# 136148        Bangalore   Economy     30.58          6  13524         13524
#
#         Price_pred
# 291541   72244.700
# 11363    10962.450
# 189930    6924.220
# 83616     4371.850
# 204174    6385.810
# ...            ...
# 46592     8722.070
# 189825    3365.630
# 125996    3927.290
# 232799   20684.000
# 136148   13697.687
#
# [100 rows x 13 columns]

# %%
# Thêm cột price_diff vào DataFrame
result['price_diff'] = abs(result['Price_actual'] - result['Price_pred'])

# In ra một số hàng để kiểm tra
result.head()
# Out:
#      airline   flight source_city departure_time stops arrival_time  \
# 0   SpiceJet  SG-8709       Delhi        Evening  zero        Night
# 4    Vistara   UK-963       Delhi        Morning  zero      Morning
# 6    Vistara   UK-927       Delhi        Morning  zero      Morning
# 10  GO_FIRST   G8-392       Delhi      Afternoon  zero      Evening
# 11  GO_FIRST   G8-338       Delhi        Morning  zero    Afternoon
#
#    destination_city    class  duration  days_left  price  Price_actual  \
# 0            Mumbai  Economy      2.17          1   5953          5953
# 4            Mumbai  Economy      2.33          1   5955          5955
# 6            Mumbai  Economy      2.08          1   6060          6060
# 10           Mumbai  Economy      2.25          1   5954          5954
# 11           Mumbai  Economy      2.33          1   5954          5954
#
#     Price_pred  price_diff
# 0      7843.22     1890.22
# 4      8975.34     3020.34
# 6      7388.06     1328.06
# 10     6414.10      460.10
# 11     6991.57     1037.57

# %%
result.describe()
# Out:
#            duration     days_left          price   Price_actual  \
# count  90046.000000  90046.000000   90046.000000   90046.000000
# mean      12.242090     25.946649   20874.981410   20874.981410
# std        7.200407     13.543974   22686.388372   22686.388372
# min        0.830000      1.000000    1105.000000    1105.000000
# 25%        6.830000     14.000000    4784.000000    4784.000000
# 50%       11.250000     26.000000    7425.000000    7425.000000
# 75%       16.170000     38.000000   42521.000000   42521.000000
# max       47.750000     49.000000  115211.000000  115211.000000
#
#           Price_pred    price_diff
# count   90046.000000  90046.000000
# mean    20922.085382    896.575002
# std     22599.438853   2203.777574
# min      1105.000000      0.000000
# 25%      4892.160000      2.590000
# 50%      7489.345000    123.845000
# 75%     42572.250000    653.730000
# max    105922.320000  44277.110000
